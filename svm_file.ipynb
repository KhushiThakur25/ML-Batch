# %% [markdown]
#  - SVM : SUPPORT VECTOR MACHINE
#
# - classification + regression
#
# - supervised learning
#
# in 1 dimension - point
# in 2 dimension - line
# in 3 dimension - plane
# in n dimension - it looks like a hyperplane
#
# -- to find the optimal classification & separation that maximizes the margin of the training data

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons,make_blobs
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# data,target = make_moons(n_samples = 500,noise = 0.1)
data,target = make_blobs(n_samples = 500,centers = 2,cluster_std = 1.0)

# %%
data.shape
# Out:
# (500, 2)

# %%
data[:5]
# Out:
# array([[-4.46100554, -1.88555013],
#        [-6.30975258, -3.29391253],
#        [-5.13511152, -1.85632124],
#        [-4.95927839, -4.53219128],
#        [-6.71022291, -2.25749994]])

# %%
plt.scatter(data[:,0],data[:,1],c= target)

# %%
def plotBoundary(pred):
    x1 = np.arange(min(data[:,0]) - 1,max(data[:,0]) + 1,step=0.01)
    x2 = np.arange(min(data[:,1]) - 1,max(data[:,1]) + 1,step=0.01)
    xx,yy = np.meshgrid(x1,x2)
    x = np.array([xx.flatten(), yy.flatten()]).T
    z = pred(x)
    z = z.reshape(xx.shape)
    plt.contourf(xx,yy,z)
    plt.scatter(data[:,0],data[:,1],c = target, cmap = 'rainbow')
    plt.show()

# %%
logistic = LogisticRegression()
logistic.fit(data,target)
# Out:
# LogisticRegression()

# %%
y_pred = logistic.predict(data)
accuracy_score(target,y_pred)
# Out:
# 1.0

# %%
plotBoundary(lambda x : logistic.predict(x))

# %%
def plotBoundary(pred):
    x1 = np.arange(min(data[:,0]) - 1,max(data[:,0]) + 1,step=0.01)
    x2 = np.arange(min(data[:,1]) - 1,max(data[:,1]) + 1,step=0.01)
    xx,yy = np.meshgrid(x1,x2)
    x = np.array([xx.flatten(), yy.flatten()]).T
    z = pred(x)
    z = z.reshape(xx.shape)
    plt.contourf(xx,yy,z)
    plt.scatter(data[:,0],data[:,1],c = target, cmap = 'rainbow')
    plt.show()

# %%
svm = SVC(kernel = 'linear')
svm.fit(data, target)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svm.predict(data)
accuracy_score(target,y_pred)
# Out:
# 1.0

# %%
plotBoundary(lambda x : svm.predict(x))
